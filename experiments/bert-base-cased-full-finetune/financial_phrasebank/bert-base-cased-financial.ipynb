# %% [markdown]
# Finetuning the model on financial_phrasebank dataset, that consists of pairs of text-labels to classify financial-related sentences, if they are either <span style="color: red;">positive</span>, <span style="color: purple;">neutral</span> or <span style="color: green;">negative</span>.

# %% [markdown]
# # 1.Experimental Setup1

# %% [markdown]
# ## 1.1 Setup

# %% [markdown]
# ## 1.2 Training

# %% [markdown]
# ### 1.2.1 Run code on CPU version

# %%
# !pwd

# %%
# !python ../../../peft_train.py \
--model_name ../../../pretrain_models/bert-base-cased \
--max_seq_len 2048 \
--group_by_length \
--max_steps 200 \
--dataset_name ../../../text-classification/financial_phrasebank \
--num_labels 3 \
--epochs 5 \
--learning_rate 1e-3 \
--model_type SEQ_CLS \
--output_model_path ./result/bert-base-cased-financial \
--need_hyperparameters_search False \
--enable_peft False \
--bnb_4bit_compute_dtype float32 \
--use_4b False
# Out:
# /Users/wengbenjue/opt/anaconda3/envs/peft/lib/python3.11/site-packages/bitsandbytes/cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# 'NoneType' object has no attribute 'cadam32bit_grad_fp32'
# /Users/wengbenjue/opt/anaconda3/envs/peft/lib/python3.11/site-packages/trl/trainer/ppo_config.py:141: UserWarning: The `optimize_cuda_cache` arguement will be deprecated soon, please use `optimize_device_cache` instead.
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at ../../../pretrain_models/bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# use AutoModelForSequenceClassification load bert model.
# trainable params: 108312579 || all params: 108312579 || trainable%: 100.0
# tokenizer padding setting: [PAD]
# Sentence: N-Viro operates processing facilities independently as well as in partnership with municipalities .
# Map: 100%|████████████████████████| 4075/4075 [00:00<00:00, 21750.04 examples/s]
# Map: 100%|██████████████████████████| 453/453 [00:00<00:00, 24595.72 examples/s]
#   0%|                                                  | 0/1270 [00:00<?, ?it/s]/Users/wengbenjue/opt/anaconda3/envs/peft/lib/python3.11/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 1.2476, 'learning_rate': 0.0009921259842519685, 'epoch': 0.04}
# {'loss': 0.9222, 'learning_rate': 0.000984251968503937, 'epoch': 0.08}
# {'loss': 0.9583, 'learning_rate': 0.0009763779527559056, 'epoch': 0.12}
# {'loss': 0.9956, 'learning_rate': 0.000968503937007874, 'epoch': 0.16}
# {'loss': 0.9512, 'learning_rate': 0.0009606299212598425, 'epoch': 0.2}
# {'loss': 1.0059, 'learning_rate': 0.000952755905511811, 'epoch': 0.24}
# {'loss': 0.9391, 'learning_rate': 0.0009448818897637795, 'epoch': 0.27}
# {'loss': 0.9184, 'learning_rate': 0.000937007874015748, 'epoch': 0.31}
# {'loss': 0.9836, 'learning_rate': 0.0009291338582677166, 'epoch': 0.35}
# {'loss': 0.9631, 'learning_rate': 0.0009212598425196851, 'epoch': 0.39}
#   8%|███▏                                    | 100/1270 [01:33<22:09,  1.14s/it]/Users/wengbenjue/opt/anaconda3/envs/peft/lib/python3.11/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 1.0474, 'learning_rate': 0.0009133858267716536, 'epoch': 0.43}
# {'loss': 0.9801, 'learning_rate': 0.000905511811023622, 'epoch': 0.47}
# {'loss': 0.9381, 'learning_rate': 0.0008976377952755906, 'epoch': 0.51}
# {'loss': 1.0117, 'learning_rate': 0.000889763779527559, 'epoch': 0.55}
# {'loss': 0.8696, 'learning_rate': 0.0008818897637795275, 'epoch': 0.59}
# {'loss': 0.9052, 'learning_rate': 0.0008740157480314961, 'epoch': 0.63}
# {'loss': 1.022, 'learning_rate': 0.0008661417322834646, 'epoch': 0.67}
# {'loss': 0.9538, 'learning_rate': 0.0008582677165354331, 'epoch': 0.71}
# {'loss': 0.8981, 'learning_rate': 0.0008503937007874016, 'epoch': 0.75}
# {'loss': 0.9188, 'learning_rate': 0.0008425196850393701, 'epoch': 0.79}
#  16%|██████▎                                 | 200/1270 [03:38<21:16,  1.19s/it]/Users/wengbenjue/opt/anaconda3/envs/peft/lib/python3.11/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 1.0117, 'learning_rate': 0.0008346456692913386, 'epoch': 0.82}
# {'loss': 0.847, 'learning_rate': 0.000826771653543307, 'epoch': 0.86}
# {'loss': 0.9642, 'learning_rate': 0.0008188976377952756, 'epoch': 0.9}
# {'loss': 0.9975, 'learning_rate': 0.0008110236220472441, 'epoch': 0.94}
# {'loss': 1.0558, 'learning_rate': 0.0008031496062992126, 'epoch': 0.98}
#  20%|████████                                | 254/1270 [05:09<28:32,  1.69s/it]
#   0%|                                                    | 0/57 [00:00<?, ?it/s]
#   4%|█▌                                          | 2/57 [00:00<00:06,  7.88it/s]
#   5%|██▎                                         | 3/57 [00:00<00:09,  5.49it/s]
#   7%|███                                         | 4/57 [00:00<00:11,  4.75it/s]
#   9%|███▊                                        | 5/57 [00:01<00:11,  4.42it/s]
#  11%|████▋                                       | 6/57 [00:01<00:12,  4.22it/s]
#  12%|█████▍                                      | 7/57 [00:01<00:11,  4.26it/s]
#  14%|██████▏                                     | 8/57 [00:01<00:11,  4.33it/s]
#  16%|██████▉                                     | 9/57 [00:01<00:11,  4.19it/s]
#  18%|███████▌                                   | 10/57 [00:02<00:12,  3.91it/s]
#  19%|████████▎                                  | 11/57 [00:02<00:11,  3.91it/s]
#  21%|█████████                                  | 12/57 [00:02<00:11,  4.08it/s]
#  23%|█████████▊                                 | 13/57 [00:02<00:10,  4.17it/s]
#  25%|██████████▌                                | 14/57 [00:03<00:10,  4.30it/s]
#  26%|███████████▎                               | 15/57 [00:03<00:10,  4.14it/s]
#  28%|████████████                               | 16/57 [00:03<00:10,  3.97it/s]
#  30%|████████████▊                              | 17/57 [00:04<00:10,  3.88it/s]
#  32%|█████████████▌                             | 18/57 [00:04<00:10,  3.82it/s]
#  33%|██████████████▎                            | 19/57 [00:04<00:09,  3.85it/s]
#  35%|███████████████                            | 20/57 [00:04<00:09,  3.83it/s]
#  37%|███████████████▊                           | 21/57 [00:05<00:09,  3.85it/s]
#  39%|████████████████▌                          | 22/57 [00:05<00:08,  4.01it/s]
site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 1.0121, 'learning_rate': 0.0007952755905511811, 'epoch': 1.02}
# {'loss': 0.9314, 'learning_rate': 0.0007874015748031497, 'epoch': 1.06}
# {'loss': 1.0643, 'learning_rate': 0.0007795275590551181, 'epoch': 1.1}
# {'loss': 0.8477, 'learning_rate': 0.0007716535433070866, 'epoch': 1.14}
# {'loss': 1.0166, 'learning_rate': 0.0007637795275590551, 'epoch': 1.18}
#  24%|█████████▍                              | 300/1270 [06:31<23:25,  1.45s/it]/Users/wengbenjue/opt/anaconda3/envs/peft/lib/python3.11/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 1.0073, 'learning_rate': 0.0007559055118110237, 'epoch': 1.22}
# {'loss': 0.9161, 'learning_rate': 0.0007480314960629921, 'epoch': 1.26}
# {'loss': 1.0224, 'learning_rate': 0.0007401574803149606, 'epoch': 1.3}
# {'loss': 0.9012, 'learning_rate': 0.0007322834645669292, 'epoch': 1.33}
# {'loss': 0.9598, 'learning_rate': 0.0007244094488188977, 'epoch': 1.37}
# {'loss': 0.962, 'learning_rate': 0.0007165354330708661, 'epoch': 1.41}
# {'loss': 0.8467, 'learning_rate': 0.0007086614173228346, 'epoch': 1.45}
# {'loss': 1.0152, 'learning_rate': 0.0007007874015748032, 'epoch': 1.49}
# {'loss': 0.9678, 'learning_rate': 0.0006929133858267717, 'epoch': 1.53}
# {'loss': 0.8874, 'learning_rate': 0.0006850393700787401, 'epoch': 1.57}
#  31%|████████████▌                           | 400/1270 [09:07<21:45,  1.50s/it]/Users/wengbenjue/opt/anaconda3/envs/peft/lib/python3.11/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.9838, 'learning_rate': 0.0006771653543307087, 'epoch': 1.61}
# {'loss': 0.9507, 'learning_rate': 0.0006692913385826772, 'epoch': 1.65}
# {'loss': 0.9204, 'learning_rate': 0.0006614173228346457, 'epoch': 1.69}
# {'loss': 1.0217, 'learning_rate': 0.0006535433070866141, 'epoch': 1.73}
# {'loss': 1.0511, 'learning_rate': 0.0006456692913385827, 'epoch': 1.77}
# {'loss': 0.9604, 'learning_rate': 0.0006377952755905512, 'epoch': 1.81}
# {'loss': 0.958, 'learning_rate': 0.0006299212598425197, 'epoch': 1.84}
# {'loss': 1.0006, 'learning_rate': 0.0006220472440944882, 'epoch': 1.88}
# {'loss': 1.007, 'learning_rate': 0.0006141732283464567, 'epoch': 1.92}
# {'loss': 0.9299, 'learning_rate': 0.0006062992125984252, 'epoch': 1.96}
#  39%|███████████████▋                        | 500/1270 [11:45<19:35,  1.53s/it]/Users/wengbenjue/opt/anaconda3/envs/peft/lib/python3.11/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#  81%|██████████████████████████████████▋        | 46/57 [00:05<00:01,  8.20it/s]
#  82%|███████████████████████████████████▍       | 47/57 [00:05<00:01,  7.90it/s]
#  84%|████████████████████████████████████▏      | 48/57 [00:05<00:01,  8.01it/s]
#  86%|████████████████████████████████████▉      | 49/57 [00:05<00:00,  8.17it/s]
#  88%|█████████████████████████████████████▋     | 50/57 [00:06<00:00,  7.82it/s]
#  89%|██████████████████████████████████████▍    | 51/57 [00:06<00:00,  8.04it/s]
#  91%|███████████████████████████████████████▏   | 52/57 [00:06<00:00,  8.03it/s]
#  93%|███████████████████████████████████████▉   | 53/57 [00:06<00:00,  7.65it/s]
#  95%|████████████████████████████████████████▋  | 54/57 [00:06<00:00,  7.46it/s]
#  96%|█████████████████████████████████████████▍ | 55/57 [00:06<00:00,  7.37it/s]
#
# {'eval_loss': 0.9294704794883728, 'eval_accuracy': 0.6136865342163356, 'eval_precision': 0.3766111622784576, 'eval_recall': 0.6136865342163356, 'eval_f1': 0.46677115324799257, 'eval_runtime': 7.1174, 'eval_samples_per_second': 63.647, 'eval_steps_per_second': 8.009, 'epoch': 2.0}
#  40%|████████████████                        | 509/1270 [12:08<19:11,  1.51s/it]
# 100%|███████████████████████████████████████████| 57/57 [00:07<00:00,  7.27it/s]
#                                                                                 /Users/wengbenjue/opt/anaconda3/envs/peft/lib/python3.11/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.9892, 'learning_rate': 0.0005984251968503937, 'epoch': 2.0}
# {'loss': 0.9535, 'learning_rate': 0.0005905511811023622, 'epoch': 2.04}
# {'loss': 0.9375, 'learning_rate': 0.0005826771653543307, 'epoch': 2.08}
# {'loss': 0.9863, 'learning_rate': 0.0005748031496062992, 'epoch': 2.12}
# {'loss': 0.9458, 'learning_rate': 0.0005669291338582678, 'epoch': 2.16}
# {'loss': 0.9187, 'learning_rate': 0.0005590551181102363, 'epoch': 2.2}
# {'loss': 0.9386, 'learning_rate': 0.0005511811023622047, 'epoch': 2.24}
# {'loss': 0.9019, 'learning_rate': 0.0005433070866141732, 'epoch': 2.28}
# {'loss': 0.9373, 'learning_rate': 0.0005354330708661418, 'epoch': 2.32}
# {'loss': 1.0054, 'learning_rate': 0.0005275590551181102, 'epoch': 2.36}
#  47%|██████████████████▉                     | 600/1270 [14:52<19:29,  1.75s/it]/Users/wengbenjue/opt/anaconda3/envs/peft/lib/python3.11/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.9426, 'learning_rate': 0.0005196850393700787, 'epoch': 2.39}
# {'loss': 0.912, 'learning_rate': 0.0005118110236220473, 'epoch': 2.43}
# {'loss': 0.9512, 'learning_rate': 0.0005039370078740158, 'epoch': 2.47}
# {'loss': 0.9358, 'learning_rate': 0.0004960629921259843, 'epoch': 2.51}
# {'loss': 0.9867, 'learning_rate': 0.0004881889763779528, 'epoch': 2.55}
# {'loss': 0.9456, 'learning_rate': 0.00048031496062992123, 'epoch': 2.59}
# {'loss': 0.9695, 'learning_rate': 0.00047244094488188977, 'epoch': 2.63}
# {'loss': 0.9611, 'learning_rate': 0.0004645669291338583, 'epoch': 2.67}
# {'loss': 1.0037, 'learning_rate': 0.0004566929133858268, 'epoch': 2.71}
# {'loss': 0.8457, 'learning_rate': 0.0004488188976377953, 'epoch': 2.75}
#  55%|██████████████████████                  | 700/1270 [18:04<16:44,  1.76s/it]/Users/wengbenjue/opt/anaconda3/envs/peft/lib/python3.11/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.975, 'learning_rate': 0.00044094488188976377, 'epoch': 2.79}
# {'loss': 0.9373, 'learning_rate': 0.0004330708661417323, 'epoch': 2.83}
# {'loss': 0.9787, 'learning_rate': 0.0004251968503937008, 'epoch': 2.87}
# {'loss': 0.9632, 'learning_rate': 0.0004173228346456693, 'epoch': 2.9}
# {'loss': 0.908, 'learning_rate': 0.0004094488188976378, 'epoch': 2.94}
# {'loss': 0.9017, 'learning_rate': 0.0004015748031496063, 'epoch': 2.98}
#  60%|████████████████████████                | 764/1270 [20:06<16:09,  1.92s/it]
#   0%|                                                    | 0/57 [00:00<?, ?it/s]
#   4%|█▌                                          | 2/57 [00:00<00:03, 14.30it/s]
#   7%|███                                         | 4/57 [00:00<00:05,  9.44it/s]
#  11%|████▋                                       | 6/57 [00:00<00:06,  7.36it/s]
#  12%|█████▍                                      | 7/57 [00:00<00:06,  7.29it/s]
#  14%|██████▏                                     | 8/57 [00:01<00:06,  7.17it/s]
#  16%|██████▉                                     | 9/57 [00:01<00:06,  7.10it/s]
#  18%|███████▌                                   | 10/57 [00:01<00:06,  7.50it/s]
#  19%|████████▎                                  | 11/57 [00:01<00:06,  7.29it/s]
#  21%|█████████                                  | 12/57 [00:01<00:06,  6.83it/s]
#  23%|█████████▊                                 | 13/57 [00:01<00:06,  7.01it/s]
#  25%|██████████▌                                | 14/57 [00:01<00:06,  7.05it/s]
#  26%|███████████▎                               | 15/57 [00:02<00:05,  7.25it/s]
#  28%|████████████                               | 16/57 [00:02<00:05,  7.13it/s]
#  30%|████████████▊                              | 17/57 [00:02<00:05,  6.83it/s]
#  32%|█████████████▌                             | 18/57 [00:02<00:06,  6.40it/s]
#  33%|██████████████▎                            | 19/57 [00:02<00:05,  6.48it/s]
#  35%|███████████████                            | 20/57 [00:02<00:05,  6.25it/s]
#  37%|███████████████▊                           | 21/57 [00:02<00:05,  6.55it/s]
#  39%|████████████████▌                          | 22/57 [00:03<00:05,  6.06it/s]
#  40%|█████████████████▎                         | 23/57 [00:03<00:05,  6.21it/s]
#  42%|██████████████████                         | 24/57 [00:03<00:05,  6.58it/s]
#  44%|██████████████████▊                        | 25/57 [00:03<00:04,  6.85it/s]
#  46%|███████████████████▌                       | 26/57 [00:03<00:04,  7.29it/s]
#  47%|████████████████████▎                      | 27/57 [00:03<00:04,  7.29it/s]
#  49%|█████████████████████                      | 28/57 [00:03<00:03,  7.40it/s]
#  51%|█████████████████████▉                     | 29/57 [00:04<00:03,  7.62it/s]
#  53%|██████████████████████▋                    | 30/57 [00:04<00:03,  7.10it/s]
#  54%|███████████████████████▍                   | 31/57 [00:04<00:03,  7.47it/s]
#  56%|████████████████████████▏                  | 32/57 [00:04<00:03,  7.35it/s]
#  58%|████████████████████████▉                  | 33/57 [00:04<00:03,  7.38it/s]
#  60%|█████████████████████████▋                 | 34/57 [00:04<00:03,  6.84it/s]
#  61%|██████████████████████████▍                | 35/57 [00:04<00:03,  6.63it/s]
#  63%|███████████████████████████▏               | 36/57 [00:05<00:03,  6.52it/s]
#  65%|███████████████████████████▉               | 37/57 [00:05<00:02,  6.69it/s]
#  67%|████████████████████████████▋              | 38/57 [00:05<00:02,  6.93it/s]
#  68%|█████████████████████████████▍             | 39/57 [00:05<00:02,  7.25it/s]
#  70%|██████████████████████████████▏            | 40/57 [00:05<00:02,  7.65it/s]
#  72%|██████████████████████████████▉            | 41/57 [00:05<00:02,  7.73it/s]
#  74%|███████████████████████████████▋           | 42/57 [00:05<00:02,  7.48it/s]
#  75%|████████████████████████████████▍          | 43/57 [00:06<00:01,  7.64it/s]
#  77%|█████████████████████████████████▏         | 44/57 [00:06<00:01,  7.06it/s]
#  79%|█████████████████████████████████▉         | 45/57 [00:06<00:01,  6.67it/s]
#  81%|██████████████████████████████████▋        | 46/57 [00:06<00:01,  6.62it/s]
#  82%|███████████████████████████████████▍       | 47/57 [00:06<00:01,  6.73it/s]
#  84%|████████████████████████████████████▏      | 48/57 [00:06<00:01,  6.83it/s]
#  86%|████████████████████████████████████▉      | 49/57 [00:06<00:01,  6.74it/s]
#  88%|█████████████████████████████████████▋     | 50/57 [00:07<00:01,  6.59it/s]
#  89%|██████████████████████████████████████▍    | 51/57 [00:07<00:00,  6.99it/s]
#  91%|███████████████████████████████████████▏   | 52/57 [00:07<00:00,  7.16it/s]
#  93%|███████████████████████████████████████▉   | 53/57 [00:07<00:00,  7.01it/s]
#  95%|████████████████████████████████████████▋  | 54/57 [00:07<00:00,  7.30it/s]
#  96%|█████████████████████████████████████████▍ | 55/57 [00:07<00:00,  7.18it/s]
#
# {'eval_loss': 0.9227004647254944, 'eval_accuracy': 0.6136865342163356, 'eval_precision': 0.3766111622784576, 'eval_recall': 0.6136865342163356, 'eval_f1': 0.46677115324799257, 'eval_runtime': 8.1617, 'eval_samples_per_second': 55.503, 'eval_steps_per_second': 6.984, 'epoch': 3.0}
#  60%|████████████████████████                | 764/1270 [20:14<16:09,  1.92s/it]
# 100%|███████████████████████████████████████████| 57/57 [00:08<00:00,  7.22it/s]
#                                                                                 /Users/wengbenjue/opt/anaconda3/envs/peft/lib/python3.11/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.9049, 'learning_rate': 0.00039370078740157485, 'epoch': 3.02}
# {'loss': 0.9481, 'learning_rate': 0.0003858267716535433, 'epoch': 3.06}
# {'loss': 1.0166, 'learning_rate': 0.0003779527559055118, 'epoch': 3.1}
# {'loss': 0.906, 'learning_rate': 0.0003700787401574803, 'epoch': 3.14}
#  63%|█████████████████████████▏              | 800/1270 [21:24<14:28,  1.85s/it]/Users/wengbenjue/opt/anaconda3/envs/peft/lib/python3.11/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 1.0137, 'learning_rate': 0.00036220472440944885, 'epoch': 3.18}
# {'loss': 0.8715, 'learning_rate': 0.0003543307086614173, 'epoch': 3.22}
# {'loss': 0.9746, 'learning_rate': 0.0003464566929133858, 'epoch': 3.26}
# {'loss': 0.91, 'learning_rate': 0.00033858267716535437, 'epoch': 3.3}
# {'loss': 0.9385, 'learning_rate': 0.00033070866141732285, 'epoch': 3.34}
# {'loss': 0.953, 'learning_rate': 0.00032283464566929134, 'epoch': 3.38}
# {'loss': 0.928, 'learning_rate': 0.00031496062992125983, 'epoch': 3.42}
# {'loss': 0.8945, 'learning_rate': 0.00030708661417322837, 'epoch': 3.45}
# {'loss': 0.8685, 'learning_rate': 0.00029921259842519685, 'epoch': 3.49}
# {'loss': 0.9145, 'learning_rate': 0.00029133858267716534, 'epoch': 3.53}
#  71%|████████████████████████████▎           | 900/1270 [24:29<11:53,  1.93s/it]/Users/wengbenjue/opt/anaconda3/envs/peft/lib/python3.11/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.949, 'learning_rate': 0.0002834645669291339, 'epoch': 3.57}
# {'loss': 0.9339, 'learning_rate': 0.00027559055118110237, 'epoch': 3.61}
# {'loss': 0.9741, 'learning_rate': 0.0002677165354330709, 'epoch': 3.65}
# {'loss': 0.9797, 'learning_rate': 0.00025984251968503934, 'epoch': 3.69}
# {'loss': 0.9768, 'learning_rate': 0.0002519685039370079, 'epoch': 3.73}
# {'loss': 1.0149, 'learning_rate': 0.0002440944881889764, 'epoch': 3.77}
# {'loss': 0.9051, 'learning_rate': 0.00023622047244094488, 'epoch': 3.81}
# {'loss': 0.9943, 'learning_rate': 0.0002283464566929134, 'epoch': 3.85}
# {'loss': 0.9283, 'learning_rate': 0.00022047244094488188, 'epoch': 3.89}
# {'loss': 0.948, 'learning_rate': 0.0002125984251968504, 'epoch': 3.93}
#  79%|██████████████████████████████▋        | 1000/1270 [27:30<08:05,  1.80s/it]/Users/wengbenjue/opt/anaconda3/envs/peft/lib/python3.11/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.9101, 'learning_rate': 0.0002047244094488189, 'epoch': 3.96}
#  80%|███████████████████████████████▎       | 1019/1270 [28:06<06:33,  1.57s/it]
#   0%|                                                    | 0/57 [00:00<?, ?it/s]
#   4%|█▌                                          | 2/57 [00:00<00:03, 14.61it/s]
#   7%|███                                         | 4/57 [00:00<00:06,  8.26it/s]
#   9%|███▊                                        | 5/57 [00:00<00:06,  7.92it/s]
#  11%|████▋                                       | 6/57 [00:00<00:07,  7.22it/s]
#  12%|█████▍                                      | 7/57 [00:00<00:06,  7.48it/s]
#  14%|██████▏                                     | 8/57 [00:01<00:06,  7.63it/s]
#  16%|██████▉                                     | 9/57 [00:01<00:06,  7.25it/s]
#  18%|███████▌                                   | 10/57 [00:01<00:06,  7.12it/s]
#  19%|████████▎                                  | 11/57 [00:01<00:06,  7.32it/s]
#  21%|█████████                                  | 12/57 [00:01<00:06,  7.28it/s]
#  89%|██████████████████████████████████████▍    | 51/57 [00:07<00:00,  6.97it/s]
#  91%|███████████████████████████████████████▏   | 52/57 [00:07<00:00,  6.49it/s]
#  93%|███████████████████████████████████████▉   | 53/57 [00:07<00:00,  6.64it/s]
#  95%|████████████████████████████████████████▋  | 54/57 [00:07<00:00,  6.80it/s]
#  96%|█████████████████████████████████████████▍ | 55/57 [00:07<00:00,  6.86it/s]
#  98%|██████████████████████████████████████████▏| 56/57 [00:07<00:00,  6.86it/s]
#
# {'eval_loss': 0.9216644763946533, 'eval_accuracy': 0.6136865342163356, 'eval_precision': 0.3766111622784576, 'eval_recall': 0.6136865342163356, 'eval_f1': 0.46677115324799257, 'eval_runtime': 8.0738, 'eval_samples_per_second': 56.107, 'eval_steps_per_second': 7.06, 'epoch': 4.0}
#  80%|███████████████████████████████▎       | 1019/1270 [28:14<06:33,  1.57s/it]
# 100%|███████████████████████████████████████████| 57/57 [00:07<00:00,  7.44it/s]
#                                                                                 /Users/wengbenjue/opt/anaconda3/envs/peft/lib/python3.11/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.846, 'learning_rate': 0.00019685039370078743, 'epoch': 4.0}
# {'loss': 0.9088, 'learning_rate': 0.0001889763779527559, 'epoch': 4.04}
# {'loss': 0.9277, 'learning_rate': 0.00018110236220472443, 'epoch': 4.08}
# {'loss': 0.9224, 'learning_rate': 0.0001732283464566929, 'epoch': 4.12}
# {'loss': 0.8641, 'learning_rate': 0.00016535433070866143, 'epoch': 4.16}
# {'loss': 0.8745, 'learning_rate': 0.00015748031496062991, 'epoch': 4.2}
# {'loss': 0.9534, 'learning_rate': 0.00014960629921259843, 'epoch': 4.24}
# {'loss': 1.0016, 'learning_rate': 0.00014173228346456694, 'epoch': 4.28}
# {'loss': 0.9543, 'learning_rate': 0.00013385826771653546, 'epoch': 4.32}
#  87%|█████████████████████████████████▊     | 1100/1270 [30:44<05:11,  1.83s/it]/Users/wengbenjue/opt/anaconda3/envs/peft/lib/python3.11/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.9015, 'learning_rate': 0.00012598425196850394, 'epoch': 4.36}
# {'loss': 0.9784, 'learning_rate': 0.00011811023622047244, 'epoch': 4.4}
# {'loss': 0.9538, 'learning_rate': 0.00011023622047244094, 'epoch': 4.44}
# {'loss': 0.9113, 'learning_rate': 0.00010236220472440946, 'epoch': 4.47}
# {'loss': 0.8754, 'learning_rate': 9.448818897637796e-05, 'epoch': 4.51}
# {'loss': 0.9835, 'learning_rate': 8.661417322834646e-05, 'epoch': 4.55}
# {'loss': 0.9836, 'learning_rate': 7.874015748031496e-05, 'epoch': 4.59}
# {'loss': 0.9168, 'learning_rate': 7.086614173228347e-05, 'epoch': 4.63}
# {'loss': 0.9056, 'learning_rate': 6.299212598425197e-05, 'epoch': 4.67}
# {'loss': 0.9471, 'learning_rate': 5.511811023622047e-05, 'epoch': 4.71}
#  94%|████████████████████████████████████▊  | 1200/1270 [33:53<02:09,  1.85s/it]/Users/wengbenjue/opt/anaconda3/envs/peft/lib/python3.11/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.8899, 'learning_rate': 4.724409448818898e-05, 'epoch': 4.75}
# {'loss': 0.9328, 'learning_rate': 3.937007874015748e-05, 'epoch': 4.79}
# {'loss': 0.8979, 'learning_rate': 3.1496062992125985e-05, 'epoch': 4.83}
# {'loss': 0.9384, 'learning_rate': 2.362204724409449e-05, 'epoch': 4.87}
# {'loss': 0.954, 'learning_rate': 1.5748031496062993e-05, 'epoch': 4.91}
# {'loss': 0.9106, 'learning_rate': 7.874015748031496e-06, 'epoch': 4.95}
# {'loss': 0.9576, 'learning_rate': 0.0, 'epoch': 4.99}
# 100%|███████████████████████████████████████| 1270/1270 [36:04<00:00,  2.06s/it]
#   0%|                                                    | 0/57 [00:00<?, ?it/s]
#   4%|█▌                                          | 2/57 [00:00<00:05, 10.85it/s]
#   7%|███                                         | 4/57 [00:00<00:06,  7.72it/s]
#   9%|███▊                                        | 5/57 [00:00<00:07,  6.86it/s]
#  11%|████▋                                       | 6/57 [00:00<00:07,  6.71it/s]
#  12%|█████▍                                      | 7/57 [00:01<00:08,  6.01it/s]
#  14%|██████▏                                     | 8/57 [00:01<00:08,  5.88it/s]
#  16%|██████▉                                     | 9/57 [00:01<00:08,  5.75it/s]
#  18%|███████▌                                   | 10/57 [00:01<00:08,  5.81it/s]
#  19%|████████▎                                  | 11/57 [00:01<00:08,  5.60it/s]
#  21%|█████████                                  | 12/57 [00:01<00:08,  5.61it/s]
#  23%|█████████▊                                 | 13/57 [00:02<00:07,  5.85it/s]
#  25%|██████████▌                                | 14/57 [00:02<00:07,  5.78it/s]
#  26%|███████████▎                               | 15/57 [00:02<00:06,  6.05it/s]
#  28%|████████████                               | 16/57 [00:02<00:06,  6.13it/s]
#  30%|████████████▊                              | 17/57 [00:02<00:06,  6.07it/s]
#  32%|█████████████▌                             | 18/57 [00:02<00:06,  6.06it/s]
#  33%|██████████████▎                            | 19/57 [00:03<00:06,  6.10it/s]
#  35%|███████████████                            | 20/57 [00:03<00:06,  6.16it/s]
#  37%|███████████████▊                           | 21/57 [00:03<00:05,  6.58it/s]
#  39%|████████████████▌                          | 22/57 [00:03<00:05,  6.64it/s]
#  40%|█████████████████▎                         | 23/57 [00:03<00:05,  6.45it/s]
#  42%|██████████████████                         | 24/57 [00:03<00:04,  6.61it/s]
#  44%|██████████████████▊                        | 25/57 [00:03<00:04,  6.55it/s]
#  46%|███████████████████▌                       | 26/57 [00:04<00:05,  6.09it/s]
#  47%|████████████████████▎                      | 27/57 [00:04<00:04,  6.03it/s]
#  49%|█████████████████████                      | 28/57 [00:04<00:04,  5.93it/s]
#  51%|█████████████████████▉                     | 29/57 [00:04<00:04,  6.10it/s]
#  53%|██████████████████████▋                    | 30/57 [00:04<00:04,  6.23it/s]
#  54%|███████████████████████▍                   | 31/57 [00:04<00:03,  6.55it/s]
#  56%|████████████████████████▏                  | 32/57 [00:05<00:03,  6.83it/s]
#  58%|████████████████████████▉                  | 33/57 [00:05<00:03,  7.02it/s]
#  60%|█████████████████████████▋                 | 34/57 [00:05<00:03,  6.97it/s]
#  61%|██████████████████████████▍                | 35/57 [00:05<00:03,  6.84it/s]
#  63%|███████████████████████████▏               | 36/57 [00:05<00:03,  6.78it/s]
#  65%|███████████████████████████▉               | 37/57 [00:05<00:02,  6.79it/s]
#  67%|████████████████████████████▋              | 38/57 [00:05<00:02,  6.94it/s]
#  68%|█████████████████████████████▍             | 39/57 [00:06<00:02,  6.32it/s]
#  70%|██████████████████████████████▏            | 40/57 [00:06<00:02,  6.79it/s]
#  72%|██████████████████████████████▉            | 41/57 [00:06<00:02,  7.14it/s]
#  74%|███████████████████████████████▋           | 42/57 [00:06<00:02,  6.44it/s]
#  75%|████████████████████████████████▍          | 43/57 [00:06<00:02,  6.28it/s]
#  77%|█████████████████████████████████▏         | 44/57 [00:06<00:02,  6.27it/s]
#  79%|█████████████████████████████████▉         | 45/57 [00:07<00:02,  5.98it/s]
#  81%|██████████████████████████████████▋        | 46/57 [00:07<00:01,  5.84it/s]
#  82%|███████████████████████████████████▍       | 47/57 [00:07<00:01,  5.95it/s]
#  84%|████████████████████████████████████▏      | 48/57 [00:07<00:01,  6.27it/s]
#  86%|████████████████████████████████████▉      | 49/57 [00:07<00:01,  6.33it/s]
#  88%|█████████████████████████████████████▋     | 50/57 [00:07<00:01,  5.93it/s]
#  89%|██████████████████████████████████████▍    | 51/57 [00:08<00:00,  6.03it/s]
#  91%|███████████████████████████████████████▏   | 52/57 [00:08<00:00,  6.00it/s]
#  93%|███████████████████████████████████████▉   | 53/57 [00:08<00:00,  6.36it/s]
#  95%|████████████████████████████████████████▋  | 54/57 [00:08<00:00,  6.33it/s]
#  96%|█████████████████████████████████████████▍ | 55/57 [00:08<00:00,  6.01it/s]
#  98%|██████████████████████████████████████████▏| 56/57 [00:08<00:00,  6.46it/s]
#
# {'eval_loss': 0.9169601202011108, 'eval_accuracy': 0.6136865342163356, 'eval_precision': 0.3766111622784576, 'eval_recall': 0.6136865342163356, 'eval_f1': 0.46677115324799257, 'eval_runtime': 9.2045, 'eval_samples_per_second': 49.215, 'eval_steps_per_second': 6.193, 'epoch': 4.99}
# 100%|███████████████████████████████████████| 1270/1270 [36:13<00:00,  2.06s/it]
# 100%|███████████████████████████████████████████| 57/57 [00:09<00:00,  5.96it/s]
# {'train_runtime': 2173.4929, 'train_samples_per_second': 9.374, 'train_steps_per_second': 0.584, 'train_loss': 0.9506112293934259, 'epoch': 4.99}
# 100%|███████████████████████████████████████| 1270/1270 [36:13<00:00,  1.71s/it]

# %% [markdown]
# ### 1.2.2 Run code on GPU version
# Load the model together with the adapter with few lines of code! Check the snippet below to load the adapter from the Hub and run the example evaluation.

# %%
# !pip install -q -U trl transformers accelerate git+https://github.com/huggingface/peft.git
# !pip install -q datasets bitsandbytes einops wandb evaluate
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks/llms-peft-cook-colab/experiments/bert-base-cased-full-finetune/financial_phrasebank

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# !python ../../../peft_train.py \
--model_name bert-base-cased \
--max_seq_len 2048 \
--group_by_length \
--max_steps 200 \
--dataset_name ../../../text-classification/financial_phrasebank \
--num_labels 3 \
--epochs 5 \
--learning_rate 1e-3\
--model_type SEQ_CLS \
--output_model_path ./result/bert-base-cased-financial-lora \
--bnb_4bit_compute_dtype float16 \
--need_hyperparameters_search False \
--enable_peft False \
--use_4b False

# %% [markdown]
# # Load your adapter from the Hub

# %%
import torch
from peft import PeftModel, PeftConfig
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

peft_model_id = "./result/flan-t5-cup-lora"
base_model_name_or_path = '.../../../pretrain_models/google-flan-t5-small'
config = PeftConfig.from_pretrained(peft_model_id)

# model = AutoModelForSeq2SeqLM.from_pretrained(config.base_model_name_or_path, torch_dtype="auto", device_map="auto")
model = AutoModelForSeq2SeqLM.from_pretrained(config.base_model_name_or_path, torch_dtype="auto", device_map="cpu")
tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)

# Load the Lora model
model = PeftModel.from_pretrained(model, peft_model_id)

# %%
model.eval()
input_text = "In January-September 2009 , the Group 's net interest income increased to EUR 112.4 mn from EUR 74.3 mn in January-September 2008 ."
inputs = tokenizer(input_text, return_tensors="pt")

outputs = model.generate(input_ids=inputs["input_ids"], max_new_tokens=10)

print("input sentence: ", input_text)
print(" output prediction: ", tokenizer.batch_decode(outputs.detach().cpu().numpy(), skip_special_tokens=True))
# Out:
# input sentence:  In January-September 2009 , the Group 's net interest income increased to EUR 112.4 mn from EUR 74.3 mn in January-September 2008 .
#  output prediction:  ['positive positive positive positive positive positive positive positive positive positive']

# %%
model.eval()
input_text = "In January-September 2009 , the Group 's net interest income increased to EUR 112.4 mn from EUR 74.3 mn in January-September 2008 ."
inputs = tokenizer(input_text, return_tensors="pt")

outputs = model.generate(input_ids=inputs["input_ids"], max_new_tokens=10)

print("input sentence: ", input_text)
print(" output prediction: ", tokenizer.batch_decode(outputs.detach().cpu().numpy(), skip_special_tokens=True))
# Out:
# input sentence:  In January-September 2009 , the Group 's net interest income increased to EUR 112.4 mn from EUR 74.3 mn in January-September 2008 .
#  output prediction:  ['positive positive positive positive positive positive positive positive positive positive']

# %% [markdown]
# ## 1.3 Experimental Result

# %%
class HTMLRender:
    def __init__(self,html_str):
        self.html_str =html_str
    def _repr_html_(self):
       return self.html_str

# %%
model_accurcy_html = '''
<table>
  <tr>
    <th>eval loss</th>
    <th>eval accuracy</th>
    <th>eval precision</th>
    <th>eval recall</th>
    <th>eval f1</th>
  </tr>
  <tr>
    <td style="background-color:#4C72B0;">0.102</td>
    <td style="background-color:#55A868;">0.896</td>
    <td style="background-color:#C44E52;">0.90</td>
     <td style="background-color:#8172B2;">0.896</td>
    <td style="background-color:#64B5CD;">0.894</td>
  </tr>

</table>

       '''
HTMLRender(model_accurcy_html)

# %%
accuracy_html = '''
<img src="./image/flan-t5-small-accuracy.png" alt="flan-t5-small-accuracy" width="70%">
'''
HTMLRender(accuracy_html)

# %%
## Load your adapter from the Hub
